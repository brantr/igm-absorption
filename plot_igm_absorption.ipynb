# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from array_io import *

# %%
fdata = "igm_absorption.2.0.txt"
l2, t2 = read_two_arrays(fdata)

# %%
fdata = "igm_absorption.3.0.txt"
l3, t3 = read_two_arrays(fdata)

# %%
fdata = "igm_absorption.4.0.txt"
l4, t4 = read_two_arrays(fdata)

# %%
fdata = "igm_absorption.5.0.txt"
l5, t5 = read_two_arrays(fdata)

# %%
fdata = "igm_absorption.6.0.txt"
l6, t6 = read_two_arrays(fdata)

# %%
fdata = "lya.txt"
za, la, ta = read_three_arrays(fdata)

# %%
plt.plot(l2,t2,color='0.5')
plt.plot(l3,t3,color='0.5')
plt.plot(l4,t4,color='0.5')
plt.plot(l5,t5,color='0.5')
plt.plot(l6,t6,color='0.5')
plt.plot(la,ta,color='red')



plt.ylim([0,1])
plt.xlim([3000,9000])
# Out:
# (3000, 9000)
